# %%
import gzip
import pickle
import numpy as np
from pathlib import Path
import torch
from  acr_bb import Observation, ACRBBenv, DefaultBranchingPolicy, RandomPolicy, LinearObservation
from fcn_training import FCNDataset, FCNBranchingPolicy, FCNNodeSelectionPolicy 

MAX_SAMPLES = 10000

N = 8 # antennas
M = 4 # users
expert_prob = 0.5

def instance_generator(M, N):
    while 1:
        yield np.random.randn(2,N,M)

# instances = np.random.randn(MAX_SAMPLES, 2, N, M)
instances = instance_generator(M,N)

env = ACRBBenv(node_select_policy_path='default')

expert_policy = DefaultBranchingPolicy()
random_policy = RandomPolicy()

episode_counter, sample_counter = 0, 0
negative_counter = 0
Path('positive_node_samples3/').mkdir(exist_ok=True)
Path('negative_node_samples3/').mkdir(exist_ok=True)

# We will solve problems (run episodes) until we have saved enough samples
max_samples_reached = False

while not max_samples_reached:
    episode_counter += 1
    
    observation_list = []
    node_indices = []
    observation, action_set, reward, done, _ = env.reset(next(instances))
    node_indices.append(env.active_node.node_index)
    observation_list.append(observation)
    while not done and reward > -5:
        if np.random.rand(1) > expert_prob:
            action_id = expert_policy.select_variable(observation, action_set)
        else:
            action_id = random_policy.select_variable(observation, action_set)

        observation, action_set, reward, done, _ = env.step(action_id)
    
    for node in env.all_nodes:
        if node.optimal:
            for i in range(len(node_indices)):
                if node_indices[i] == node.node_index:
                    data = [observation_list[i], True]
                    break
        else:
            for i in range(len(node_indices)):
                if node_indices[i] == node.node_index:
                    data = [observation_list[i], False]
                    break

            
        if not max_samples_reached:
            if node.optimal:
                filename = f'positive_node_samples3/sample_{sample_counter}.pkl'
                sample_counter += 1
                
            else:
                filename = f'negative_node_samples3/sample_{negative_counter}.pkl'
                negative_counter += 1
            with gzip.open(filename, 'wb') as f:
                pickle.dump(data, f)
            # If we collected enough samples, we finish the current episode but stop saving samples
            if sample_counter >= MAX_SAMPLES:
                max_samples_reached = True
                break;
    print(f"Episode {episode_counter}, {sample_counter}, {negative_counter} samples collected so far")
# Out:
# Episode 1, 26, 649 samples collected so far
# Episode 2, 52, 1910 samples collected so far
# Episode 3, 75, 2240 samples collected so far
# Episode 4, 89, 2337 samples collected so far
# Episode 5, 114, 3127 samples collected so far
# Episode 6, 135, 5187 samples collected so far
# Episode 7, 161, 6050 samples collected so far
# Episode 8, 188, 7796 samples collected so far
# Episode 9, 207, 7948 samples collected so far
# Episode 10, 233, 8327 samples collected so far
# Episode 11, 259, 9058 samples collected so far
# Episode 12, 285, 9521 samples collected so far
# Episode 13, 307, 10442 samples collected so far
# Episode 14, 336, 13270 samples collected so far
# Episode 15, 363, 15708 samples collected so far
# Episode 16, 387, 17623 samples collected so far
# Episode 17, 414, 18039 samples collected so far
# Episode 18, 437, 18507 samples collected so far
# Episode 19, 465, 19190 samples collected so far
# Episode 20, 483, 19405 samples collected so far
# Episode 21, 506, 20279 samples collected so far
# Episode 22, 529, 20351 samples collected so far
# Episode 23, 559, 20646 samples collected so far
# Episode 24, 588, 21708 samples collected so far
# Episode 25, 613, 23264 samples collected so far
# Episode 26, 639, 24637 samples collected so far
# Episode 27, 667, 25532 samples collected so far
# Episode 28, 695, 25731 samples collected so far
# Episode 29, 718, 26311 samples collected so far
# Episode 30, 739, 27497 samples collected so far
# Episode 31, 762, 27763 samples collected so far
# Episode 32, 790, 29062 samples collected so far
# Episode 33, 816, 29565 samples collected so far
# Episode 34, 841, 30127 samples collected so far
# Episode 35, 866, 30581 samples collected so far
# Episode 36, 896, 31234 samples collected so far
# Episode 37, 920, 34627 samples collected so far
# Episode 38, 954, 36980 samples collected so far
# Episode 39, 982, 38123 samples collected so far
# Episode 40, 1009, 38885 samples collected so far
# Episode 41, 1034, 39157 samples collected so far
# Episode 42, 1062, 39600 samples collected so far
# Episode 43, 1087, 40002 samples collected so far
# Episode 44, 1106, 40882 samples collected so far
# Episode 45, 1134, 41923 samples collected so far
# Episode 46, 1164, 42728 samples collected so far
# Episode 47, 1184, 43015 samples collected so far
# Episode 48, 1208, 44028 samples collected so far
# Episode 49, 1233, 44638 samples collected so far
# Episode 50, 1262, 45548 samples collected so far
# Episode 51, 1292, 45953 samples collected so far
# Episode 52, 1322, 46616 samples collected so far
# Episode 53, 1348, 47179 samples collected so far
# Episode 54, 1373, 47471 samples collected so far
# Episode 55, 1389, 47746 samples collected so far
# Episode 56, 1419, 48661 samples collected so far
# Episode 57, 1447, 49046 samples collected so far
# Episode 58, 1467, 49657 samples collected so far
# Episode 59, 1490, 51595 samples collected so far
# Episode 60, 1516, 52866 samples collected so far
# Episode 61, 1543, 53480 samples collected so far
# Episode 62, 1568, 54146 samples collected so far
# Episode 63, 1592, 54937 samples collected so far
# Episode 64, 1616, 56016 samples collected so far
# Episode 65, 1643, 56484 samples collected so far
# Episode 66, 1670, 57392 samples collected so far
# Episode 67, 1696, 57769 samples collected so far
# Episode 68, 1720, 58564 samples collected so far
# Episode 69, 1739, 59272 samples collected so far
# Episode 70, 1765, 59761 samples collected so far
# Episode 71, 1789, 60312 samples collected so far
# Episode 72, 1813, 61003 samples collected so far
# Episode 73, 1835, 61474 samples collected so far
# Episode 74, 1858, 61892 samples collected so far
# Episode 75, 1884, 62967 samples collected so far
# Episode 76, 1909, 63813 samples collected so far
# Episode 77, 1933, 64196 samples collected so far
# Episode 78, 1955, 65573 samples collected so far
# Episode 79, 1980, 66029 samples collected so far
# Episode 80, 2008, 66920 samples collected so far
# Episode 81, 2034, 67597 samples collected so far
# Episode 82, 2064, 68944 samples collected so far
# Episode 83, 2093, 71166 samples collected so far
# Episode 84, 2119, 72475 samples collected so far
# Episode 85, 2148, 72955 samples collected so far
# Episode 86, 2168, 74410 samples collected so far
# Episode 87, 2194, 75085 samples collected so far
# Episode 88, 2219, 75385 samples collected so far
# Episode 89, 2242, 76341 samples collected so far
# Episode 90, 2269, 78031 samples collected so far
# Episode 91, 2290, 78363 samples collected so far
# Episode 92, 2316, 78734 samples collected so far
# Episode 93, 2342, 79387 samples collected so far
# Episode 94, 2367, 80159 samples collected so far
# Episode 95, 2395, 81112 samples collected so far
# Episode 96, 2421, 83363 samples collected so far
# Episode 97, 2450, 84023 samples collected so far
# Episode 98, 2473, 84565 samples collected so far
# Episode 99, 2491, 84692 samples collected so far
# Episode 100, 2518, 85618 samples collected so far
# Episode 101, 2537, 85968 samples collected so far
# Episode 102, 2562, 86324 samples collected so far
# Episode 103, 2591, 88212 samples collected so far
# Episode 104, 2617, 88773 samples collected so far
# Episode 105, 2646, 89347 samples collected so far
# Episode 106, 2668, 90268 samples collected so far
# Episode 107, 2693, 90826 samples collected so far
# Episode 108, 2722, 91986 samples collected so far
# Episode 109, 2741, 92550 samples collected so far
# Episode 110, 2768, 93762 samples collected so far
# Episode 111, 2792, 94469 samples collected so far
# Episode 112, 2810, 95056 samples collected so far
# Episode 113, 2835, 97256 samples collected so far
# Episode 114, 2863, 97707 samples collected so far
# Episode 115, 2890, 98323 samples collected so far
# Episode 116, 2916, 98898 samples collected so far
# Episode 117, 2937, 99648 samples collected so far
# Episode 118, 2960, 100910 samples collected so far
# Episode 119, 2986, 101729 samples collected so far
# Episode 120, 3011, 102223 samples collected so far
# Episode 121, 3037, 102530 samples collected so far
# Episode 122, 3070, 103350 samples collected so far
# Episode 123, 3097, 103932 samples collected so far
# Episode 124, 3121, 104109 samples collected so far
# Episode 125, 3149, 105834 samples collected so far
# Episode 126, 3176, 107346 samples collected so far
# Episode 127, 3196, 107729 samples collected so far
# Episode 128, 3222, 108430 samples collected so far
# Episode 129, 3250, 111329 samples collected so far
# Episode 130, 3270, 112440 samples collected so far
# Episode 131, 3292, 113185 samples collected so far
# Episode 132, 3319, 113863 samples collected so far
# Episode 133, 3346, 114343 samples collected so far
# Episode 134, 3377, 114707 samples collected so far
# Episode 135, 3405, 116224 samples collected so far
# Episode 136, 3431, 116857 samples collected so far
# Episode 137, 3455, 117242 samples collected so far
# Episode 138, 3480, 117706 samples collected so far
# Episode 139, 3505, 118966 samples collected so far
# Episode 140, 3530, 119122 samples collected so far
# Episode 141, 3558, 119401 samples collected so far
# Episode 142, 3583, 120121 samples collected so far
# Episode 143, 3606, 120979 samples collected so far
# Episode 144, 3632, 121506 samples collected so far
# Episode 145, 3655, 122432 samples collected so far
# Episode 146, 3685, 123825 samples collected so far
# Episode 147, 3710, 125719 samples collected so far
# Episode 148, 3735, 127623 samples collected so far
# Episode 149, 3758, 128157 samples collected so far
# Episode 150, 3787, 129115 samples collected so far
# Episode 151, 3808, 130011 samples collected so far
# Episode 152, 3834, 130668 samples collected so far
# Episode 153, 3855, 130932 samples collected so far
# Episode 154, 3880, 131276 samples collected so far
# Episode 155, 3903, 131688 samples collected so far
# Episode 156, 3935, 132873 samples collected so far
# Episode 157, 3964, 133221 samples collected so far
# Episode 158, 3986, 133810 samples collected so far
# Episode 159, 4014, 134845 samples collected so far
# Episode 160, 4038, 135200 samples collected so far
# Episode 161, 4061, 136248 samples collected so far
# Episode 162, 4087, 137279 samples collected so far
# Episode 163, 4113, 138264 samples collected so far
# Episode 164, 4138, 138918 samples collected so far
# Episode 165, 4164, 140359 samples collected so far
# Episode 166, 4191, 141585 samples collected so far
# Episode 167, 4214, 142095 samples collected so far
# Episode 168, 4243, 143347 samples collected so far
# Episode 169, 4267, 144696 samples collected so far
# Episode 170, 4293, 145261 samples collected so far
# Episode 171, 4316, 145623 samples collected so far
# Episode 172, 4343, 146787 samples collected so far
# Episode 173, 4366, 148193 samples collected so far
# Episode 174, 4394, 148656 samples collected so far
# Episode 175, 4422, 152031 samples collected so far
# Episode 176, 4449, 152889 samples collected so far
# Episode 177, 4477, 153494 samples collected so far
# Episode 178, 4505, 154289 samples collected so far
# Episode 179, 4531, 154860 samples collected so far
# Episode 180, 4553, 155473 samples collected so far
# Episode 181, 4581, 157106 samples collected so far
# Episode 182, 4607, 158007 samples collected so far
# Episode 183, 4628, 159279 samples collected so far
# Episode 184, 4647, 159825 samples collected so far
# Episode 185, 4673, 160638 samples collected so far
# Episode 186, 4697, 160987 samples collected so far
# Episode 187, 4720, 161455 samples collected so far
# Episode 188, 4745, 162415 samples collected so far
# Episode 189, 4768, 165501 samples collected so far
# Episode 190, 4795, 166333 samples collected so far
# Episode 191, 4819, 167020 samples collected so far
# Episode 192, 4838, 167388 samples collected so far
# Episode 193, 4868, 168633 samples collected so far
# Episode 194, 4895, 168823 samples collected so far
# Episode 195, 4921, 169206 samples collected so far
# Episode 196, 4951, 169679 samples collected so far
# Episode 197, 4976, 170957 samples collected so far
# Episode 198, 4997, 171121 samples collected so far
# Episode 199, 5023, 171800 samples collected so far
# Episode 200, 5049, 172147 samples collected so far
# Episode 201, 5075, 173016 samples collected so far
# Episode 202, 5101, 174003 samples collected so far
# Episode 203, 5128, 174595 samples collected so far
# Episode 204, 5155, 175347 samples collected so far
# Episode 205, 5180, 176433 samples collected so far
# Episode 206, 5203, 177237 samples collected so far
# Episode 207, 5231, 177540 samples collected so far
# Episode 208, 5255, 177643 samples collected so far
# Episode 209, 5281, 178692 samples collected so far
# Episode 210, 5309, 180515 samples collected so far
# Episode 211, 5334, 181113 samples collected so far
# Episode 212, 5355, 181583 samples collected so far
# Episode 213, 5381, 182746 samples collected so far
# Episode 214, 5406, 184380 samples collected so far
# Episode 215, 5429, 186782 samples collected so far
# Episode 216, 5454, 188830 samples collected so far
# Episode 217, 5481, 189450 samples collected so far
# Episode 218, 5508, 189826 samples collected so far
# Episode 219, 5536, 190691 samples collected so far
# Episode 220, 5554, 190944 samples collected so far
# Episode 221, 5577, 191154 samples collected so far
# Episode 222, 5602, 192514 samples collected so far
# Episode 223, 5623, 193320 samples collected so far
# Episode 224, 5650, 195366 samples collected so far
# Episode 225, 5674, 195861 samples collected so far
# Episode 226, 5700, 197206 samples collected so far
# Episode 227, 5724, 197533 samples collected so far
# Episode 228, 5753, 198555 samples collected so far
# Episode 229, 5773, 198758 samples collected so far
# Episode 230, 5798, 200802 samples collected so far
# Episode 231, 5828, 201663 samples collected so far
# Episode 232, 5843, 201803 samples collected so far
# Episode 233, 5863, 202452 samples collected so far
# Episode 234, 5882, 203058 samples collected so far
# Episode 235, 5909, 203542 samples collected so far
# Episode 236, 5936, 204314 samples collected so far
# Episode 237, 5963, 206176 samples collected so far
# Episode 238, 5986, 206508 samples collected so far
# Episode 239, 6014, 207091 samples collected so far
# Episode 240, 6039, 207509 samples collected so far
# Episode 241, 6066, 208305 samples collected so far
# Episode 242, 6093, 209149 samples collected so far
# Episode 243, 6119, 209564 samples collected so far
# Episode 244, 6134, 209870 samples collected so far
# Episode 245, 6157, 210248 samples collected so far
# Episode 246, 6183, 211313 samples collected so far
# Episode 247, 6208, 215173 samples collected so far
# Episode 248, 6234, 215712 samples collected so far
# Episode 249, 6257, 216358 samples collected so far
# Episode 250, 6282, 216920 samples collected so far
# Episode 251, 6303, 217160 samples collected so far
# Episode 252, 6324, 217776 samples collected so far
# Episode 253, 6350, 218413 samples collected so far
# Episode 254, 6377, 219525 samples collected so far
# Episode 255, 6405, 220192 samples collected so far
# Episode 256, 6431, 220809 samples collected so far
# Episode 257, 6443, 221292 samples collected so far
# Episode 258, 6464, 222736 samples collected so far
# Episode 259, 6491, 224124 samples collected so far
# Episode 260, 6518, 224752 samples collected so far
# Episode 261, 6544, 225011 samples collected so far
# Episode 262, 6564, 225766 samples collected so far
# Episode 263, 6591, 226998 samples collected so far
# Episode 264, 6606, 227526 samples collected so far
# Episode 265, 6634, 228277 samples collected so far
# Episode 266, 6661, 229175 samples collected so far
# Episode 267, 6689, 229448 samples collected so far
# Episode 268, 6714, 229984 samples collected so far
# Episode 269, 6739, 230958 samples collected so far
# Episode 270, 6764, 232184 samples collected so far
# Episode 271, 6792, 233369 samples collected so far
# Episode 272, 6819, 235087 samples collected so far
# Episode 273, 6840, 235217 samples collected so far
# Episode 274, 6871, 235543 samples collected so far
# Episode 275, 6896, 236925 samples collected so far
# Episode 276, 6920, 237378 samples collected so far
# Episode 277, 6946, 238333 samples collected so far
# Episode 278, 6972, 239050 samples collected so far
# Episode 279, 7000, 240311 samples collected so far
# Episode 280, 7026, 240980 samples collected so far
# Episode 281, 7051, 241354 samples collected so far
# Episode 282, 7076, 242790 samples collected so far
# Episode 283, 7104, 243337 samples collected so far
# Episode 284, 7130, 244046 samples collected so far
# Episode 285, 7149, 244918 samples collected so far
# Episode 286, 7173, 246433 samples collected so far
# Episode 287, 7200, 248151 samples collected so far
# Episode 288, 7223, 249277 samples collected so far
# Episode 289, 7246, 249871 samples collected so far
# Episode 290, 7271, 250263 samples collected so far
# Episode 291, 7297, 250752 samples collected so far
# Episode 292, 7328, 251526 samples collected so far
# Episode 293, 7351, 252266 samples collected so far
# Episode 294, 7378, 253658 samples collected so far
# Episode 295, 7403, 254192 samples collected so far
# Episode 296, 7431, 254999 samples collected so far
# Episode 297, 7455, 255962 samples collected so far
# Episode 298, 7483, 256505 samples collected so far
# Episode 299, 7510, 256813 samples collected so far
# Episode 300, 7536, 257474 samples collected so far
# Episode 301, 7560, 258279 samples collected so far
# Episode 302, 7579, 258991 samples collected so far
# Episode 303, 7609, 260506 samples collected so far
# Episode 304, 7636, 261306 samples collected so far
# Episode 305, 7661, 261900 samples collected so far
# Episode 306, 7687, 262167 samples collected so far
# Episode 307, 7713, 263168 samples collected so far
# Episode 308, 7738, 264130 samples collected so far
# Episode 309, 7761, 265970 samples collected so far
# Episode 310, 7782, 266364 samples collected so far
# Episode 311, 7801, 266738 samples collected so far
# Episode 312, 7829, 269141 samples collected so far
# Episode 313, 7854, 271823 samples collected so far
# Episode 314, 7880, 274562 samples collected so far
# Episode 315, 7908, 275391 samples collected so far
# Episode 316, 7934, 276182 samples collected so far
# Episode 317, 7963, 277184 samples collected so far
# Episode 318, 7981, 277315 samples collected so far
# Episode 319, 8005, 277950 samples collected so far
# Episode 320, 8034, 278716 samples collected so far
# Episode 321, 8061, 279038 samples collected so far
# Episode 322, 8086, 279946 samples collected so far
# Episode 323, 8110, 280307 samples collected so far
# Episode 324, 8135, 280695 samples collected so far
# Episode 325, 8163, 281008 samples collected so far
# Episode 326, 8189, 281949 samples collected so far
# Episode 327, 8208, 282397 samples collected so far
# Episode 328, 8231, 283353 samples collected so far
# Episode 329, 8259, 284238 samples collected so far
# Episode 330, 8285, 285205 samples collected so far
# Episode 331, 8312, 287775 samples collected so far
# Episode 332, 8334, 289614 samples collected so far
# Episode 333, 8360, 290857 samples collected so far
# Episode 334, 8388, 291392 samples collected so far
# Episode 335, 8414, 291831 samples collected so far
# Episode 336, 8439, 292961 samples collected so far
# Episode 337, 8463, 294416 samples collected so far
# Episode 338, 8489, 294713 samples collected so far
# Episode 339, 8517, 295616 samples collected so far
# Episode 340, 8541, 296129 samples collected so far
# Episode 341, 8569, 296322 samples collected so far
# Episode 342, 8598, 297162 samples collected so far
# Episode 343, 8627, 298042 samples collected so far
# Episode 344, 8649, 299301 samples collected so far
# Episode 345, 8675, 299946 samples collected so far
# Episode 346, 8707, 300675 samples collected so far
# Episode 347, 8732, 302923 samples collected so far
# Episode 348, 8758, 303888 samples collected so far
# Episode 349, 8783, 304376 samples collected so far
# Episode 350, 8810, 304888 samples collected so far
# Episode 351, 8831, 305010 samples collected so far
# Episode 352, 8855, 305673 samples collected so far
# Episode 353, 8883, 306334 samples collected so far
# Episode 354, 8909, 307123 samples collected so far
# Episode 355, 8936, 307687 samples collected so far
# Episode 356, 8962, 308204 samples collected so far
# Episode 357, 8991, 308516 samples collected so far
# Episode 358, 9016, 309388 samples collected so far
# Episode 359, 9043, 309948 samples collected so far
# Episode 360, 9069, 311391 samples collected so far
# Episode 361, 9094, 311707 samples collected so far
# Episode 362, 9121, 312701 samples collected so far
# Episode 363, 9146, 312845 samples collected so far
# Episode 364, 9166, 314182 samples collected so far
# Episode 365, 9192, 315695 samples collected so far
# Episode 366, 9213, 316225 samples collected so far
# Episode 367, 9245, 317356 samples collected so far
# Episode 368, 9268, 317732 samples collected so far
# Episode 369, 9297, 320678 samples collected so far
# Episode 370, 9327, 321203 samples collected so far
# Episode 371, 9352, 324047 samples collected so far
# Episode 372, 9380, 324572 samples collected so far
# Episode 373, 9398, 324841 samples collected so far
# Episode 374, 9420, 327038 samples collected so far
# Episode 375, 9447, 327438 samples collected so far
# Episode 376, 9477, 327909 samples collected so far
# Episode 377, 9506, 328351 samples collected so far
# Episode 378, 9530, 329140 samples collected so far
# Episode 379, 9550, 329871 samples collected so far
# Episode 380, 9571, 330429 samples collected so far
# Episode 381, 9597, 331304 samples collected so far
# Episode 382, 9619, 331961 samples collected so far
# Episode 383, 9643, 332648 samples collected so far
# Episode 384, 9672, 335052 samples collected so far
# Episode 385, 9699, 335802 samples collected so far
# Episode 386, 9719, 336541 samples collected so far
# Episode 387, 9748, 336737 samples collected so far
# Episode 388, 9775, 338601 samples collected so far
# Episode 389, 9802, 340443 samples collected so far
# Episode 390, 9827, 341717 samples collected so far
# Episode 391, 9852, 342627 samples collected so far
# Episode 392, 9878, 343594 samples collected so far
# Episode 393, 9899, 344214 samples collected so far
# Episode 394, 9922, 345326 samples collected so far
# Episode 395, 9948, 346123 samples collected so far
# Episode 396, 9976, 346778 samples collected so far
# Episode 397, 10000, 347232 samples collected so far
