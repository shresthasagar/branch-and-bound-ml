# %%
import numpy as np
import itertools
from beamforming import solve_beamforming_with_selected_antennas
from multiprocessing import Pool
from as_omar import as_omar
# from as_bb import solve_bb, DefaultBranchingPolicy
# from as_bb import ASBBenv as Environment

from as_bb_test import solve_bb, DefaultBranchingPolicy
from as_bb_test import ASBBenv as Environment
import os
import pickle
import time
from pathlib import Path
from antenna_selection.observation import Observation
from model_tester import solve_bb_pool, solve_ml_pool

N = 12
M = 8
max_ant = 4
np.random.seed(seed = 100)
num_egs = 30

ftpl = []
nonftpl = []

folder_path = '/scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/validation_set/N={},M={},L={}_ftpl'.format(N,M,max_ant)

if not os.path.isdir(folder_path):
    Path(folder_path).mkdir(exist_ok=True)

result_filepath = os.path.join(folder_path, 'egs_set_1_seed_100.pkl') 

MODEL_FOLDERPATH = '/scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N={},M={},L={}'.format(N,M,max_ant)

num_nodes_eval = 0
time_total = 0
obj_bb = 0
obj_omar = 0
obj_opt = 0
t1 = time.time()

instances = np.random.randn(num_egs, 2, N, M)

######### ORACLE method #####################

# t1 = time.time()
# arguments_oracle = list(zip(list(instances), [max_ant]*num_egs))
# # with Pool(10) as p:
# #     out_oracle = p.map(solve_bb_pool, arguments_oracle)
# #     print('pool ended')
# # oracle_time = time.time() - t1
# out_oracle =[]
# for i in range(num_egs):
#     print('eg {}'.format(i))
#     output = solve_bb_pool(arguments_oracle[i])
#     out_oracle.append(output)

# optimal_solution_list = [out_oracle[i][0] for i in range(len(out_oracle))]
# optimal_objective_list = [out_oracle[i][1] for i in range(len(out_oracle))]
# oracle_time = np.mean([out_oracle[i][3] for i in range(len(out_oracle))])

# data = (instances, optimal_solution_list, optimal_objective_list, oracle_time)
# with open(result_filepath, 'wb') as handle:
#     pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)    

########### LOAD data ################################################

with open(result_filepath, 'rb') as handle:
    data = pickle.load(handle)
    instances, optimal_solution_list, optimal_objective_list, oracle_time = data

########## OMAR'S Method #######################################
# mask_omar = []
# omar_time = 0
# for i in range(num_egs):
#     H = instances[i,0,:,:] + 1j*instances[i,1,:,:]
#     obj_bb += optimal_objective_list[i]
#     t1 = time.time()
#     obj, mask = as_omar(H, max_ant=max_ant)
#     omar_time += time.time() - t1
#     obj_omar += obj
#     mask_omar.append(mask)
# omar_time = omar_time/num_egs
# print(omar_time)


########### GNN MODEL ###################################


### FTPL ###
mask_omar = [np.zeros(N)]*num_egs
for i in range(4, 5):
    MODEL_FILEPATH = os.path.join(MODEL_FOLDERPATH, 'gnn_ftpl3_iter_{}'.format(i))
    t1 = time.time()
    arguments_ml = list(zip(list(instances), optimal_solution_list, optimal_objective_list, range(num_egs), [MODEL_FILEPATH]*num_egs, [max_ant]*num_egs, mask_omar, [False]*num_egs))
    
    out_ml =[]
    for i in range(num_egs):
        print('eg {}'.format(i))
        output = solve_ml_pool(arguments_ml[i])
        out_ml.append(output)

#     with Pool(30) as p:
#         out_ml = p.map(solve_ml_pool, arguments_ml)
    
    avg_ml_ogap = np.mean(np.array([out_ml[i][1] for i in range(len(out_ml))]))
    avg_ml_steps = np.mean(np.array([out_ml[i][0] for i in range(len(out_ml))]))
    ml_time = np.mean(np.array([out_ml[i][2] for i in range(len(out_ml))]))
    ftpl.append((avg_ml_ogap, avg_ml_steps, ml_time))

### NON-FTPL ###
# for i in range(19, 20):
#     MODEL_FILEPATH = os.path.join(MODEL_FOLDERPATH, 'gnn_nonftpl_iter_{}'.format(i))
#     t1 = time.time()
#     arguments_ml = list(zip(list(instances), optimal_solution_list, optimal_objective_list, range(num_egs), [MODEL_FILEPATH]*num_egs, [max_ant]*num_egs, mask_omar))
    
#     out_ml =[]
#     for i in range(num_egs):
#         print('eg {}'.format(i))
#         output = solve_ml_pool(arguments_ml[i])
#         out_ml.append(output)
    
# #     with Pool(10) as p:
# #         out_ml = p.map(solve_ml_pool, arguments_ml)
    
#     avg_ml_ogap = np.mean(np.array([out_ml[i][1] for i in range(len(out_ml))]))
#     avg_ml_steps = np.mean(np.array([out_ml[i][0] for i in range(len(out_ml))]))
#     ml_time = np.mean(np.array([out_ml[i][2] for i in range(len(out_ml))]))
#     nonftpl.append((avg_ml_ogap, avg_ml_steps, ml_time))

# mydict = {'ftpl': ftpl, 'nonftpl': nonftpl, 'omar':(omar_time, oracle_time, obj_omar, obj_bb)}
# output = open('ftpl_nonftpl_test.pkl', 'wb')
# pickle.dump(mydict, output)
# output.close()
# Out:
# eg 0
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=12,M=8,L=4/gnn_ftpl3_iter_4
# /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/as_bb_test.py:436: RuntimeWarning: invalid value encountered in double_scalars
#   if (self.global_U - self.global_L)/abs(self.global_U) < self.epsilon:
# timestep 0
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.006524562835693359
# /scratch/sagar/Projects/combopt/venv/lib/python3.6/site-packages/cvxpy/reductions/solvers/solving_chain.py:167: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Discplined Parametrized Programming, at
# 	https://www.cvxpy.org/tutorial/advanced/index.html#disciplined-parametrized-programming
#   warnings.warn(dpp_error_msg)
# Push children Time 0.6376006603240967
# timestep 1
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0036978721618652344
# Push children Time 0.615776538848877
# timestep 2
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003291606903076172
# Push children Time 0.5034067630767822
# timestep 3
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003269195556640625
# Push children Time 0.4283313751220703
# timestep 4
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003161907196044922
# timestep 4
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0024373531341552734
# timestep 4
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002331972122192383
# Push children Time 0.4736924171447754
# timestep 5
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003324270248413086
# timestep 5
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0028378963470458984
# timestep 5
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002794027328491211
# Push children Time 0.4788689613342285
# timestep 6
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0031197071075439453
# timestep 6
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0026586055755615234
# Push children Time 0.5070271492004395
# timestep 7
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.005881309509277344
# timestep 7
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0026929378509521484
# Push children Time 0.4711880683898926
# timestep 8
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003241300582885742
# timestep 8
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0026578903198242188
# instance result 8 101.48481998749253 4.126552581787109 5 3.767733304451285 7.591410666082475
# eg 1
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=12,M=8,L=4/gnn_ftpl3_iter_4
# timestep 0
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0030863285064697266
# Push children Time 0.6347386837005615
# timestep 1
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003340005874633789
# Push children Time 0.4849569797515869
# timestep 2
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003056764602661133
# Push children Time 0.5656940937042236
# timestep 3
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0033388137817382812
# Push children Time 0.41044068336486816
# timestep 4
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003002643585205078
# Push children Time 0.46734619140625
# timestep 5
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003260374069213867
# Push children Time 0.5155572891235352
# timestep 6
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0034399032592773438
# Push children Time 0.4053456783294678
# timestep 7
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0033080577850341797
# Push children Time 0.467484712600708
# timestep 8
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.0032007694244384766
# Push children Time 0.5408785343170166
# timestep 9
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0032296180725097656
# Push children Time 0.5141353607177734
# timestep 10
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003134489059448242
# Push children Time 0.47652196884155273
# timestep 48
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0033037662506103516
# timestep 48
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0024945735931396484
# Push children Time 0.3939657211303711
# timestep 49
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.003240823745727539
# timestep 49
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.0027544498443603516
# timestep 49
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0024750232696533203
# timestep 49
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026988983154296875
# Push children Time 0.5047576427459717
# timestep 50
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0033359527587890625
# timestep 50
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0024759769439697266
# timestep 50
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002796173095703125
# timestep 50
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002672433853149414
# timestep 50
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002752542495727539
# timestep 50
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0024809837341308594
# timestep 50
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0024089813232421875
# instance result 50 17.638347331724553 23.47376322746277 5 3.595102880076599 4.229219612997342
# eg 2
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=12,M=8,L=4/gnn_ftpl3_iter_4
# timestep 0
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0031642913818359375
# Push children Time 0.5515463352203369
# timestep 1
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0032863616943359375
# Push children Time 0.49889302253723145
# timestep 2
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003270387649536133
# Push children Time 0.486156702041626
# timestep 3
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.003179788589477539
# Push children Time 0.3716294765472412
# timestep 4
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003010988235473633
# Push children Time 0.4538719654083252
# timestep 5
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0032384395599365234
# Push children Time 0.5050094127655029
# timestep 6
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002906322479248047
# Push children Time 0.4333202838897705
# timestep 7
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003172636032104492
# timestep 7
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028073787689208984
# timestep 7
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002750873565673828
# Push children Time 0.3942220211029053
# timestep 8
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.00319671630859375
# timestep 8
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0025026798248291016
# Push children Time 0.4374406337738037
# timestep 9
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0037992000579833984
# Push children Time 0.4912750720977783
# timestep 10
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0029489994049072266
# timestep 10
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0025255680084228516
# Push children Time 0.45331716537475586
# timestep 11
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0031375885009765625
# timestep 11
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002596616744995117
# Push children Time 0.4593634605407715
# timestep 12
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0031015872955322266
# Push children Time 0.45424485206604004
# timestep 13
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003028392791748047
# timestep 13
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0025682449340820312
# Push children Time 0.4514293670654297
# timestep 14
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002919435501098633
# Push children Time 0.48309779167175293
# timestep 15
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028259754180908203
# timestep 15
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0022373199462890625
# Push children Time 0.4400472640991211
# timestep 16
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0031130313873291016
# Push children Time 0.46115994453430176
# timestep 17
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0029871463775634766
# Push children Time 0.48126673698425293
# timestep 18
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0031054019927978516
# Push children Time 0.45126819610595703
# timestep 19
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.003368377685546875
# timestep 19
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002418994903564453
# Push children Time 0.4418501853942871
# timestep 20
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0029158592224121094
# timestep 20
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026187896728515625
# Push children Time 0.468719482421875
# timestep 21
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.0031948089599609375
# timestep 21
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026307106018066406
# Push children Time 0.4926917552947998
# timestep 22
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0033888816833496094
# Push children Time 0.37999987602233887
# timestep 23
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003294706344604492
# Push children Time 0.36426854133605957
# timestep 24
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003167390823364258
# Push children Time 0.38747143745422363
# timestep 25
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0029959678649902344
# Push children Time 0.3818032741546631
# timestep 26
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0031409263610839844
# Push children Time 0.5435078144073486
# timestep 27
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0032634735107421875
# Push children Time 0.36686158180236816
# timestep 28
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028564929962158203
# Push children Time 0.4662282466888428
# timestep 29
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030603408813476562
# Push children Time 0.4820058345794678
# timestep 30
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003237485885620117
# Push children Time 0.4222729206085205
# timestep 31
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002728700637817383
# Push children Time 0.4948146343231201
# timestep 32
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.00262451171875
# Push children Time 0.41480350494384766
# timestep 33
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0028336048126220703
# Push children Time 0.5112547874450684
# timestep 34
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003306865692138672
# Push children Time 0.4231443405151367
# timestep 35
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0031585693359375
# Push children Time 0.39725232124328613
# timestep 36
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0025594234466552734
# Push children Time 0.4216320514678955
# timestep 23
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028426647186279297
# Push children Time 0.473590612411499
# timestep 24
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003239870071411133
# timestep 24
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0026128292083740234
# timestep 24
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002486705780029297
# Push children Time 0.379744291305542
# timestep 25
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003024578094482422
# timestep 25
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0027463436126708984
# timestep 25
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002667665481567383
# Push children Time 0.39302539825439453
# timestep 26
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0034275054931640625
# Push children Time 0.4856748580932617
# timestep 27
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0030846595764160156
# Push children Time 0.4437849521636963
# timestep 28
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.00310516357421875
# timestep 28
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002475738525390625
# Push children Time 0.3997204303741455
# timestep 29
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.003345012664794922
# Push children Time 0.4894442558288574
# timestep 30
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0030443668365478516
# Push children Time 0.43546199798583984
# timestep 31
# Selection Time 7.62939453125e-06
# Prune Decision Time 0.002839326858520508
# Push children Time 0.3981146812438965
# timestep 32
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0030477046966552734
# Push children Time 0.3837423324584961
# timestep 33
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0037391185760498047
# Push children Time 0.4267866611480713
# timestep 34
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0027618408203125
# Push children Time 0.4513871669769287
# timestep 35
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003149747848510742
# Push children Time 0.3697693347930908
# timestep 36
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0029342174530029297
# Push children Time 0.512427806854248
# timestep 37
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.003197193145751953
# timestep 37
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002553224563598633
# Push children Time 0.3703029155731201
# timestep 38
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0033011436462402344
# Push children Time 0.3916900157928467
# timestep 39
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003000020980834961
# Push children Time 0.481433629989624
# timestep 40
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003100872039794922
# Push children Time 0.40202879905700684
# timestep 41
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003087282180786133
# Push children Time 0.4531130790710449
# timestep 42
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0032546520233154297
# timestep 42
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028238296508789062
# timestep 42
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002613544464111328
# timestep 42
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026657581329345703
# Push children Time 0.36070990562438965
# timestep 43
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003282308578491211
# timestep 43
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.00232696533203125
# timestep 43
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.0022912025451660156
# timestep 43
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0022704601287841797
# timestep 43
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.002255678176879883
# Push children Time 0.3382101058959961
# instance result 44 0.0 20.06579041481018 10 5.491072831697681 5.491072831697681
# eg 4
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=12,M=8,L=4/gnn_ftpl3_iter_4
# timestep 0
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002894878387451172
# Push children Time 0.612318754196167
# timestep 1
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.003312349319458008
# Push children Time 0.4458746910095215
# timestep 2
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.003232717514038086
# Push children Time 0.5213272571563721
# timestep 3
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030279159545898438
# Push children Time 0.4538612365722656
# timestep 4
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0032434463500976562
# Push children Time 0.37814807891845703
# timestep 5
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0027632713317871094
# Push children Time 0.43109679222106934
# timestep 6
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003134012222290039
# Push children Time 0.4976625442504883
# timestep 7
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030150413513183594
# timestep 7
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002522706985473633
# Push children Time 0.5390849113464355
# timestep 8
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.003469705581665039
# timestep 8
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027391910552978516
# Push children Time 0.4721379280090332
# timestep 9
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002987384796142578
# Push children Time 0.4487731456756592
# timestep 10
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.003270864486694336
# timestep 10
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002813100814819336
# Push children Time 0.4776427745819092
# timestep 11
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0031499862670898438
# timestep 11
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0027320384979248047
# Push children Time 0.4649341106414795
# timestep 12
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.0038857460021972656
# Push children Time 0.405181884765625
# timestep 13
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0029120445251464844
# Push children Time 0.42789363861083984
# timestep 14
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003113985061645508
# timestep 14
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.0022933483123779297
# timestep 14
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002211332321166992
# timestep 14
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0022020339965820312
# Push children Time 0.474292516708374
# timestep 15
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.003027200698852539
# timestep 15
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026311874389648438
# Push children Time 0.5152466297149658
# timestep 16
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028934478759765625
# Push children Time 0.4942049980163574
# timestep 39
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0034744739532470703
# timestep 39
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002731800079345703
# timestep 39
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028162002563476562
# timestep 39
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028350353240966797
# Push children Time 0.44829750061035156
# timestep 40
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0034110546112060547
# timestep 40
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002679586410522461
# Push children Time 0.3717660903930664
# timestep 41
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0026874542236328125
# timestep 41
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.0023496150970458984
# Push children Time 0.4207882881164551
# timestep 42
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.0031614303588867188
# timestep 42
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0027213096618652344
# instance result 42 10.52314383344783 18.70348596572876 2 2.807588738119765 3.1030353392837906
# eg 7
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=12,M=8,L=4/gnn_ftpl3_iter_4
# timestep 0
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003120899200439453
# Push children Time 0.5603823661804199
# timestep 1
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0031380653381347656
# Push children Time 0.49266624450683594
# timestep 2
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0032396316528320312
# Push children Time 0.5838284492492676
# timestep 3
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002931356430053711
# Push children Time 0.47516417503356934
# timestep 4
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.00310516357421875
# Push children Time 0.4809439182281494
# timestep 5
# Selection Time 7.152557373046875e-07
# ...
# Push children Time 0.4255223274230957
# timestep 26
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030641555786132812
# Push children Time 0.4637746810913086
# timestep 27
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.002925395965576172
# Push children Time 0.453061580657959
# timestep 28
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0030384063720703125
# timestep 28
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002542257308959961
# Push children Time 0.5124497413635254
# timestep 29
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0031058788299560547
# timestep 29
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0024976730346679688
# Push children Time 0.4004702568054199
# timestep 30
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0029251575469970703
# Push children Time 0.6143491268157959
# timestep 31
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003612041473388672
# timestep 31
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0024518966674804688
# Push children Time 0.5024840831756592
# timestep 32
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002936124801635742
# timestep 32
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0024840831756591797
# Push children Time 0.3946371078491211
# timestep 33
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0035657882690429688
# Push children Time 0.49108028411865234
# timestep 34
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027472972869873047
# timestep 34
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002248048782348633
# Push children Time 0.38692784309387207
# timestep 35
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002878427505493164
# Push children Time 0.5588338375091553
# timestep 36
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002919435501098633
# timestep 36
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0022437572479248047
# Push children Time 0.4715242385864258
# timestep 37
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0028183460235595703
# Push children Time 0.4859931468963623
# timestep 38
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0030388832092285156
# Push children Time 0.3972039222717285
# timestep 39
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003107786178588867
# timestep 39
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002475261688232422
# Push children Time 0.41323208808898926
# timestep 40
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002802610397338867
# Push children Time 0.5620653629302979
# timestep 41
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003101348876953125
# Push children Time 0.4993305206298828
# timestep 42
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0030579566955566406
# Push children Time 0.3501861095428467
# timestep 43
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030808448791503906
# timestep 43
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003018617630004883
# timestep 43
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0024633407592773438
# timestep 43
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.0023527145385742188
# timestep 43
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002362489700317383
# timestep 43
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002344369888305664
# timestep 43
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0022118091583251953
# timestep 43
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002182483673095703
# Push children Time 0.45572519302368164
# timestep 44
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0028133392333984375
# timestep 44
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0022935867309570312
# timestep 44
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0024209022521972656
# instance result 44 44.29863834861143 20.506855010986328 5 4.34540249808348 6.270356635501008
# eg 28
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=12,M=8,L=4/gnn_ftpl3_iter_4
# timestep 0
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002826690673828125
# Push children Time 0.5964164733886719
# timestep 1
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0029191970825195312
# Push children Time 0.47987818717956543
# timestep 2
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0028123855590820312
# Push children Time 0.4983329772949219
# timestep 3
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026628971099853516
# Push children Time 0.4530651569366455
# timestep 4
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.003019571304321289
# Push children Time 0.5284943580627441
# timestep 5
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.00293731689453125
# timestep 5
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002412557601928711
# Push children Time 0.5336790084838867
# timestep 6
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.003017425537109375
# Push children Time 0.4552779197692871
# timestep 7
# Selection Time 1.430511474609375e-06
# Prune Decision Time 0.0035016536712646484
# timestep 7
# Selection Time 1.1920928955078125e-06
# Prune Decision Time 0.0029535293579101562
# timestep 7
# Selection Time 1.6689300537109375e-06
# Prune Decision Time 0.002875089645385742
# timestep 7
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026693344116210938
# Push children Time 0.5413804054260254
# timestep 8
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030982494354248047
# Push children Time 0.4656221866607666
# timestep 9
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.003020763397216797
# Push children Time 0.40822386741638184
# timestep 10
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002908945083618164
# Push children Time 0.5086278915405273
# timestep 11
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.003001689910888672
# Push children Time 0.3808605670928955
# timestep 12
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0032291412353515625
# Push children Time 0.4207339286804199
# timestep 13
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0025758743286132812
# Push children Time 0.3989386558532715
# timestep 14
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.00234222412109375
# Push children Time 0.39243507385253906
# timestep 15
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0024094581604003906
# Push children Time 0.5015883445739746
# timestep 16
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.0028884410858154297
# Push children Time 0.4109337329864502
# timestep 17
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002844572067260742
# Push children Time 0.4084346294403076
# timestep 18
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002920389175415039
# Push children Time 0.39233946800231934
# timestep 19
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0023043155670166016
# Push children Time 0.48447155952453613
# timestep 20
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0028748512268066406
# Push children Time 0.43632054328918457
# timestep 21
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002874612808227539
# Push children Time 0.3445742130279541
# timestep 22
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.00279998779296875
# Push children Time 0.4364914894104004
# timestep 23
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002848386764526367
# timestep 23
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002423524856567383
# Push children Time 0.38280224800109863
# timestep 24
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0029485225677490234
# Push children Time 0.49532341957092285
# timestep 25
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.003126859664916992
# Push children Time 0.36753249168395996
# timestep 26
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0027627944946289062
# Push children Time 0.31761598587036133
# timestep 27
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002779245376586914
# Push children Time 0.40334105491638184
# timestep 28
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027892589569091797
# Push children Time 0.3627939224243164
# timestep 29
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002672910690307617
# timestep 29
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002444028854370117
# timestep 29
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.002382516860961914
# Push children Time 0.40380024909973145
# timestep 30
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027914047241210938
# timestep 30
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0024251937866210938
# timestep 30
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0022430419921875
# instance result 30 16.108846980648746 13.235372304916382 9 3.61377771785912 4.195915640649826
# eg 29
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=12,M=8,L=4/gnn_ftpl3_iter_4
# timestep 0
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.0027306079864501953
# Push children Time 0.6385376453399658
# timestep 1
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030274391174316406
# Push children Time 0.4918704032897949
# timestep 2
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028607845306396484
# Push children Time 0.5483481884002686
# timestep 3
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028963088989257812
# Push children Time 0.4878997802734375
# timestep 4
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0028810501098632812
# Push children Time 0.45128726959228516
# timestep 5
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0029294490814208984
# Push children Time 0.4940621852874756
# timestep 6
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0029900074005126953
# timestep 6
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0023145675659179688
# Push children Time 0.5397017002105713
# timestep 7
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0024230480194091797
# timestep 7
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002141714096069336
# Push children Time 0.5334649085998535
# timestep 8
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026984214782714844
# Push children Time 0.4451904296875
# timestep 9
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.002854585647583008
# Push children Time 0.4290792942047119
# timestep 10
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027761459350585938
# Push children Time 0.47385263442993164
# timestep 11
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027420520782470703
# timestep 11
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002328634262084961
# Push children Time 0.5016071796417236
# timestep 12
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0029327869415283203
# Push children Time 0.5817549228668213
# timestep 13
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002708911895751953
# timestep 13
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0021517276763916016
# timestep 13
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0021991729736328125
# Push children Time 0.43015074729919434
# timestep 14
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.002858400344848633
# timestep 14
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002249479293823242
# Push children Time 0.5054714679718018
# timestep 15
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0023927688598632812
# Push children Time 0.40669751167297363
# timestep 16
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002750396728515625
# Push children Time 0.5267307758331299
# timestep 17
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0027687549591064453
# Push children Time 0.4909191131591797
# timestep 18
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002598285675048828
# timestep 18
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0020461082458496094
# Push children Time 0.587465763092041
# timestep 19
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002849578857421875
# Push children Time 0.4928576946258545
# timestep 20
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0029866695404052734
# timestep 20
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0023317337036132812
# Push children Time 0.4246225357055664
# timestep 21
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0025763511657714844
# Push children Time 0.40584349632263184
# timestep 22
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028791427612304688
# Push children Time 0.4074380397796631
# timestep 23
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002899169921875
# timestep 23
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0023272037506103516
# timestep 23
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002165079116821289
# Push children Time 0.4985013008117676
# timestep 24
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002869844436645508
# timestep 24
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0023276805877685547
# Push children Time 0.4424448013305664
# timestep 25
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0027265548706054688
# timestep 25
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002239227294921875
# timestep 25
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0023193359375
# Push children Time 0.41405153274536133
# timestep 26
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027475357055664062
# Push children Time 0.5001201629638672
# timestep 27
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0029582977294921875
# Push children Time 0.40999722480773926
# timestep 28
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028650760650634766
# Push children Time 0.40088486671447754
# timestep 29
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.002640247344970703
# Push children Time 0.49878740310668945
# timestep 30
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0027480125427246094
# timestep 30
# Selection Time 2.384185791015625e-07
# Prune Decision Time 0.0024785995483398438
# timestep 30
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002300739288330078
# Push children Time 0.3546130657196045
# timestep 31
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0028133392333984375
# Push children Time 0.4749612808227539
# timestep 32
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.003107786178588867
# Push children Time 0.405989408493042
# timestep 33
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.002939939498901367
# Push children Time 0.4469730854034424
# timestep 34
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0030694007873535156
# Push children Time 0.4086885452270508
# timestep 35
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0029723644256591797
# Push children Time 0.48900580406188965
# timestep 36
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0027587413787841797
# timestep 36
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0022776126861572266
# Push children Time 0.4380025863647461
# timestep 37
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002519369125366211
# timestep 37
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0021657943725585938
# Push children Time 0.4430978298187256
# timestep 38
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0031898021697998047
# timestep 38
# Selection Time 4.76837158203125e-07
# Prune Decision Time 0.0026092529296875
# timestep 38
# Selection Time 7.152557373046875e-07
# Prune Decision Time 0.0026290416717529297
# timestep 38
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.002374887466430664
# timestep 38
# Selection Time 9.5367431640625e-07
# Prune Decision Time 0.0023016929626464844
# instance result 38 9.415259230601599 17.955134868621826 5 5.605676755440215 6.133465753594488

# %%
for i in range(3, 4):
    MODEL_FILEPATH = os.path.join(MODEL_FOLDERPATH, 'gnn_ftpl3_iter_{}'.format(i))
    t1 = time.time()
    arguments_ml = list(zip(list(instances), optimal_solution_list, optimal_objective_list, range(num_egs), [MODEL_FILEPATH]*num_egs, [max_ant]*num_egs, mask_omar, [False]*num_egs))
    
    out_ml =[]
    for i in range(num_egs):
        print('eg {}'.format(i))
        output = solve_ml_pool(arguments_ml[i])
        out_ml.append(output)

# %%
out_ml
# Out:
# [(21, -100.0, 10.133156538009644, 0.09302325581395349)]

# %%
ftpl
# Out:
# [(0.029194360739263545, 6.133333333333334, 1.8398040850957236)]

# %%
nonftpl
# Out:
# [(0.12670382597441848, 5.433333333333334, 2.3564427057902018)]

# %%
oracle_time
# Out:
# 18.27560358842214

# %%
oracle_time/ftpl[0][2]
# Out:
# 9.933450923646186

# %%
oracle_time/nonftpl[0][2]
# Out:
# 7.755590044059085

# %%
oracle_time/omar_time
# Out:
# 29.263759585789835

# %%
oracle

# %%
omar_time
# Out:
# 0.6245131810506185

# %%
(obj_omar-obj_bb)/(obj_bb)*100
# Out:
# 2.36632545782786

# %%
import pickle
output = open('ftpl_nonftpl_test.pkl', 'rb')
data = pickle.load(output)

# %%
data['ftpl']
# Out:
# [(0.2694953207157567, 5.64, 14.697339482307434)]

# %%
5.64

# %%
data['nonftpl']
# Out:
# [(0.16084924055821895, 6.05, 6.8126283812522885)]

# %%
data['omar']
# Out:
# (2.7278252387046815, 61.97380712032318, 32.261608724378846, 31.729752941806517)

# %%
data['omar'][0]
# Out:
# 2.7278252387046815

# %%
61.97*1/0.94
# Out:
# 65.92553191489363

# %%
61.97*1/6.81
# Out:
# 9.09985315712188

# %%
omar = data['omar']

# %%
(omar[2]-omar[3])/omar[3]*100
# Out:
# 1.6762052435383632

# %%
print(omar_time, obj_omar)
print(ftpl)
print(nonftpl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-33bd88c62bc1> in <module>
# ----> 1 print(omar_time, obj_omar)
#       2 print(ftpl)
#       3 print(nonftpl)
#
# NameError: name 'omar_time' is not defined

# %%
    
avg_ml_ogap = np.mean(np.array([out_ml[i][1] for i in range(len(out_ml))]))
avg_ml_steps = np.mean(np.array([out_ml[i][0] for i in range(len(out_ml))]))
ml_time = np.mean(np.array([out_ml[i][2] for i in range(len(out_ml))]))
ftpl.append((avg_ml_ogap, avg_ml_steps, ml_time))

### NON-FTPL ###
for i in range(2, 30):
    MODEL_FILEPATH = os.path.join(MODEL_FOLDERPATH, 'gnn_nonftpl_iter_{}'.format(i))
    t1 = time.time()
    arguments_ml = list(zip(list(instances), optimal_solution_list, optimal_objective_list, range(num_egs), [MODEL_FILEPATH]*num_egs, [max_ant]*num_egs, mask_omar))
    
    out_ml =[]
    for i in range(num_egs):
        print('eg {}'.format(i))
        output = solve_ml_pool(arguments_ml[i])
        out_ml.append(output)
    
#     with Pool(num_egs) as p:
#         out_ml = p.map(solve_ml_pool, arguments_ml)
    
    avg_ml_ogap = np.mean(np.array([out_ml[i][1] for i in range(len(out_ml))]))
    avg_ml_steps = np.mean(np.array([out_ml[i][0] for i in range(len(out_ml))]))
    ml_time = np.mean(np.array([out_ml[i][2] for i in range(len(out_ml))]))
    nonftpl.append((avg_ml_ogap, avg_ml_steps, ml_time))
# Out:
# /scratch/sagar/Projects/combopt/venv/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /scratch/sagar/Projects/combopt/venv/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# eg 0
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_2
# timestep 0
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# timestep 3
# timestep 4
# timestep 4
# timestep 5
# timestep 5
# instance result 5 0.0 5.001058340072632 3 0.2261046114899136 0.2261046114899136
# eg 1
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_2
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 3
# timestep 3
# timestep 4
# timestep 4
# instance result 4 0.0 4.802222967147827 4 0.4469534929346341 0.4469534929346341
# eg 2
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_2
# timestep 0
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# timestep 3
# timestep 3
# instance result 3 -100.0 3.0615837574005127 3 0.7209357118082166 0.0
# eg 3
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_2
# timestep 0
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# timestep 3
# timestep 3
# instance result 3 -100.0 2.567876100540161 3 0.451974904468021 0.0
# eg 4
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_2
# timestep 0
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# timestep 3
# timestep 3
# instance result 3 -100.0 3
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 8.588072776794434 3 0.3010937148947479 0.3010937148947479
# eg 17
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 11.160385847091675 3 0.5922744365712596 0.5922744365712596
# eg 18
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 4.683861092749452 10.902265310287476 4 0.43305146726830696 0.4533349964552678
# eg 19
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 9.584798097610474 3 0.42380208664816094 0.42380208664816094
# eg 20
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 4.406682741966563 9.455047607421875 4 0.6395397165615243 0.6677222028792629
# eg 21
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 14.828512062145688 11.246131181716919 3 0.4613294167668289 0.5297377049783245
# eg 22
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 10.661543846130371 3 0.2678400041380617 0.2678400041380617
# eg 23
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 12.270206689834595 3 0.7310933503543672 0.7310933503543672
# eg 24
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# timestep 4
# timestep 5
# timestep 6
# instance result 7 0.0 21.268614292144775 7 0.4884241612928177 0.4884241612928177
# eg 25
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 11.335197687149048 3 0.3463062857297205 0.3463062857297205
# eg 26
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 10.54002571105957 3 0.553712399584306 0.553712399584306
# eg 27
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# timestep 4
# instance result 4 0.0 12.788084030151367 5 0.34884330791352597 0.34884330791352597
# eg 28
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# instance result 3 0.0 11.853916645050049 3 0.6599860664577335 0.6599860664577335
# eg 29
# policy path /scratch/sagar/Projects/combopt/branch-and-bound-ml/antenna_selection/trained_models/N=8,M=3,L=5/gnn_nonftpl_iter_29
# timestep 0
# timestep 1
# timestep 1
# timestep 2
# timestep 2
# timestep 3
# timestep 4
# instance result 4 0.0 11.56438422203064 5 0.29610568105651963 0.29610568105651963

# %%
len(arguments_ml)
# Out:
# 30

# %%
obj_omar
# Out:
# 14.210075124710375

# %%
len(mask_omar)
# Out:
# 30

# %%
instances.shape
# Out:
# (200, 2, 8, 3)

# %%
np.array([out_ml[i][1] for i in range(len(out_ml))])
# Out:
# (30,)

# %%
ftpl
# Out:
# [(1.255419426611621, 7.2, 16.21217370033264),
#  (1.255419426611621, 8.1, 18.546713145573936),
#  (1.255419426611621, 7.333333333333333, 16.557219775517783),
#  (1.1230160216842786, 7.466666666666667, 17.142367617289224),
#  (1.1230160216842786, 7.8, 17.477919419606526),
#  (1.1230160216842786, 7.4, 16.622257947921753),
#  (1.8621126632404263, 5.833333333333333, 11.803038914998373),
#  (0.7045797271434697, 7.466666666666667, 15.922824478149414),
#  (1.1268574332798476, 6.6, 13.618681875864665),
#  (0.8876454286314162, 7.4, 15.368161010742188),
#  (0.5721763222161272, 7.866666666666666, 17.291396832466127),
#  (1.1230160216842786, 7.066666666666666, 13.913981413841247),
#  (0.6732719001482192, 7.733333333333333, 16.24602789878845),
#  (1.323467215836378, 8.1, 16.967158087094624),
#  (1.5741359009144877, 6.7, 13.176199253400167),
#  (0.9467428349668758, 7.266666666666667, 13.97390178044637),
#  (1.0232962014463363, 6.633333333333334, 12.89444534778595),
#  (0.8124409206181807, 7.133333333333334, 13.923590493202209),
#  (1.307431552176706, 6.533333333333333, 12.77270069917043),
#  (1.307431552176706, 6.766666666666667, 13.584559981028239)]

# %%
ftpl
# Out:
# [(0.4892293766720052, 7.17, 3.989533984661102)]

# %%
ftpl
# Out:
# [(0.5721763222161284, 7.866666666666666, 16.781735634803773)]

# %%
nonftpl
# Out:
# [(0.7045797271434708, 7.933333333333334, 17.245376205444337)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2,1, figsize=(10,10))

offset = 2
x = np.arange(len(ftpl)-1)+2
axes[0].plot(x, [ftpl[i][0] for i in range(len(ftpl)-1)])
axes[0].plot(x, [nonftpl[i][0] for i in range(len(nonftpl))])
axes[0].set_ylim([-0.1, 3])
axes[0].set_xlabel('Iteration')
axes[0].set_ylabel('Ogap (%)')

axes[0].legend(['ftpl', 'non-ftpl'])

axes[1].plot(x, [oracle_time/ftpl[i][2] for i in range(len(ftpl)-1)])
axes[1].plot(x, [oracle_time/nonftpl[i][2] for i in range(len(nonftpl))])
# axes[1].set_ylim([-0.1, 3])
axes[1].set_xlabel('Iteration')
axes[1].set_ylabel('Speedup')
axes[1].legend(['ftpl', 'non-ftpl'])

# %%
len(ftpl)
# Out:
# 29

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,1)

offset = 2
x = np.arange(len(data['ftpl']))+2
axes.plot(x, data['ftpl'] )
axes.plot(x, data['nonftpl'])
axes.set_ylim([-0.1, 3])
axes.set_xlabel('Iteration')
axes.set_ylabel('Ogap (%)')
axes.legend(['FTPL', 'FTL'])

# %%
fig.savefig('data/ftpl_ftl_comparison.pdf')

# %%
data['nonftpl']
# Out:
# array([5.08635571e+03, 1.59212964e+00, 1.59212964e+00, 1.59212964e+00,
#        1.68380634e+00, 1.59212964e+00, 1.59212964e+00, 1.59212964e+00,
#        1.68380634e+00, 1.59212964e+00, 1.17331473e+00, 1.68380634e+00,
#        1.68380634e+00, 1.68380634e+00, 1.59212964e+00, 1.59212964e+00,
#        1.59212964e+00, 9.61051843e-01, 1.68380634e+00, 1.51562438e+00,
#        1.06860121e+00, 1.60730108e+00, 1.59212964e+00, 1.60730108e+00,
#        2.18229534e+00, 1.60730108e+00, 1.27953897e+00, 1.68380634e+00])

# %%
(data['ftpl'])
# Out:
# array([1.15242853, 0.85633832, 1.51247771, 1.30336149, 1.59212964,
#        1.59212964, 1.09784591, 1.59212964, 1.68380634, 1.59212964,
#        1.59212964, 1.59212964, 1.68380634, 1.68380634, 1.59212964,
#        1.59212964, 1.68380634, 1.06860121, 1.68380634, 0.98894928,
#        1.59212964, 1.68380634, 1.59212964, 1.59212964, 1.59212964,
#        1.20564006, 0.85633832, 1.08062598])

# %%
nonftpl
# Out:
# [(5086.355713752996, 3.2, 2.9489835500717163),
#  (1.5921296425737657, 4.2, 3.6322306474049886),
#  (1.5921296425737657, 4.133333333333334, 3.50801366964976),
#  (1.5921296425737657, 4.133333333333334, 3.364587966601054),
#  (1.6838063384216242, 3.8333333333333335, 4.0397932211558025),
#  (1.5921296425737657, 4.166666666666667, 5.555583961804708),
#  (1.5921296425737657, 4.2, 6.081245032946269),
#  (1.5921296425737657, 4.466666666666667, 5.761310410499573),
#  (1.6838063384216242, 5.233333333333333, 6.314946715037028),
#  (1.5921296425737657, 4.7, 5.490511417388916),
#  (1.1733147330830598, 5.233333333333333, 6.402869447072347),
#  (1.6838063384216242, 4.666666666666667, 5.978234640757242),
#  (1.6838063384216242, 4.533333333333333, 5.663325357437134),
#  (1.6838063384216242, 4.266666666666667, 5.3491776069005335),
#  (1.5921296425737657, 4.833333333333333, 6.1508806069691975),
#  (1.5921296425737657, 4.4, 13.92465759118398),
#  (1.5921296425737657, 4.366666666666666, 12.725847864151001),
#  (0.9610518433903162, 6.2, 14.72514185110728),
#  (1.6838063384216242, 4.333333333333333, 14.044646088282267),
#  (1.51562438142588, 4.666666666666667, 9.911357259750366),
#  (1.0686012120287662, 5.966666666666667, 16.157395044962566),
#  (1.607301077273739, 4.4, 11.933746767044067),
#  (1.5921296425737657, 4.433333333333334, 6.692206247647603),
#  (1.607301077273739, 4.433333333333334, 9.281234033902486),
#  (2.1822953390324735, 4.466666666666667, 12.820975613594054),
#  (1.607301077273739, 4.833333333333333, 8.48266818523407),
#  (1.2795389700261548, 5.566666666666666, 8.324747959772745),
#  (1.6838063384216242, 4.033333333333333, 12.50020935535431)]

# %%
ftpl
# Out:
# [(1.1524285305467126, 7.933333333333334, 2.7749309460322062),
#  (0.8563383223360225, 6.4, 2.202965672810872),
#  (1.5124777102425426, 4.4, 1.6548226674397786),
#  (1.3033614917331369, 5.166666666666667, 2.097409661610921),
#  (1.5921296425737657, 4.033333333333333, 1.4071082512537638),
#  (1.5921296425737657, 5.166666666666667, 2.034865077336629),
#  (1.0978459071689093, 5.033333333333333, 1.7783133109410605),
#  (1.5921296425737657, 4.733333333333333, 1.622014625867208),
#  (1.6838063384216242, 4.233333333333333, 1.4281996011734008),
#  (1.5921296425737657, 4.7, 2.011378836631775),
#  (1.5921296425737657, 4.333333333333333, 1.6833046118418376),
#  (1.5921296425737657, 5.1, 1.87189994653066),
#  (1.6838063384216242, 4.533333333333333, 1.730306625366211),
#  (1.6838063384216242, 4.3, 1.4615776538848877),
#  (1.5921296425737657, 4.933333333333334, 2.012334680557251),
#  (1.5921296425737657, 4.533333333333333, 1.5115286827087402),
#  (1.6838063384216242, 3.8666666666666667, 1.8644436597824097),
#  (1.0686012120287662, 5.633333333333334, 1.9423084020614625),
#  (1.6838063384216242, 4.333333333333333, 1.6741314331690471),
#  (0.9889492796975433, 6.366666666666666, 2.3039220412572226),
#  (1.5921296425737657, 4.666666666666667, 1.649182931582133),
#  (1.6838063384216242, 4.266666666666667, 1.8042945384979248),
#  (1.5921296425737657, 4.6, 1.7362709840138753),
#  (1.5921296425737657, 5.033333333333333, 2.299747522672017),
#  (1.5921296425737657, 4.4, 1.8613269170125326),
#  (1.205640060768656, 4.9, 2.1184927145640056),
#  (0.8563383223360225, 6.8, 2.693071436882019),
#  (1.0806259755454022, 5.733333333333333, 2.1939218441645303),
#  (nan, nan, nan)]

# %%
1/6.8/40
# Out:
# 0.003676470588235294

# %%
fig.savefig('data/results/plt_compare_ftpl_nonftpl2.pdf')

# %%
ftpl_result = np.array([ftpl[i][0] for i in range(len(ftpl)-1)])
nonftpl_result = np.array([nonftpl[i][0] for i in range(len(ftpl)-1)])
omar_stat = {'time': omar_time, 'Ogap':3.20, 'oracle_time':oracle_time}
mydict = {'ftpl': ftpl_result, 'nonftpl': nonftpl_result, 'omar':omar_stat}
output = open('ftpl_nonftpl_validation.pkl', 'wb')
pickle.dump(mydict, output)
output.close()

# %%
np.argmin( [ftpl[i][0] for i in range(len(ftpl))])
# Out:
# 7

# %%
filename ='ftpl_nonftpl_validation.pkl'
import pickle

with open(filename, 'rb') as handle:
    data = pickle.load(handle)

# %%
data['omar']
# Out:
# {'time': 0.7665881554285685, 'Ogap': 3.2, 'oracle_time': 11.455091094970703}

# %%
data['ftpl']
# Out:
# array([1.15242853, 0.85633832, 1.51247771, 1.30336149, 1.59212964,
#        1.59212964, 1.09784591, 1.59212964, 1.68380634, 1.59212964,
#        1.59212964, 1.59212964, 1.68380634, 1.68380634, 1.59212964,
#        1.59212964, 1.68380634, 1.06860121, 1.68380634, 0.98894928,
#        1.59212964, 1.68380634, 1.59212964, 1.59212964, 1.59212964,
#        1.20564006, 0.85633832, 1.08062598])

# %%
import numpy as np

np.argmin(data['nonftpl'])
# Out:
# 17

# %%
data['nonftpl']
# Out:
# array([5.08635571e+03, 1.59212964e+00, 1.59212964e+00, 1.59212964e+00,
#        1.68380634e+00, 1.59212964e+00, 1.59212964e+00, 1.59212964e+00,
#        1.68380634e+00, 1.59212964e+00, 1.17331473e+00, 1.68380634e+00,
#        1.68380634e+00, 1.68380634e+00, 1.59212964e+00, 1.59212964e+00,
#        1.59212964e+00, 9.61051843e-01, 1.68380634e+00, 1.51562438e+00,
#        1.06860121e+00, 1.60730108e+00, 1.59212964e+00, 1.60730108e+00,
#        2.18229534e+00, 1.60730108e+00, 1.27953897e+00, 1.68380634e+00])

# %%
data

# %%
mask_omar = [np.zeros(N) for _ in range(num_egs)]

t1 = time.time()

offset = 0
arguments_ml = list(zip(list(instances)[offset:], optimal_solution_list[offset:], optimal_objective_list[offset:], range(num_egs), [MODEL_FILEPATH]*num_egs, [max_ant]*num_egs, mask_omar))

out_ml =[]
for i in range(num_egs):
    output = collect_data_instance(arguments_ml[i])
    out_ml.append(output)
    

avg_ml_ogap = np.mean(np.array([out_ml[i][1] for i in range(len(out_ml))]))
avg_ml_steps = np.mean(np.array([out_ml[i][0] for i in range(len(out_ml))]))
ml_time = np.mean(np.array([out_ml[i][2] for i in range(len(out_ml))]))

# time profiling
misc_time =           np.mean(np.array([out_ml[i][4][0] for i in range(len(out_ml))]))
classification_time = np.mean(np.array([out_ml[i][4][1] for i in range(len(out_ml))]))
branching_time =      np.mean(np.array([out_ml[i][4][2] for i in range(len(out_ml))]))
classified_nodes =    np.mean(np.array([out_ml[i][4][3] for i in range(len(out_ml))]))
branched_nodes =      np.mean(np.array([out_ml[i][4][4] for i in range(len(out_ml))]))

print('Model ogap: {}, time speedup: {}'.format(avg_ml_ogap, oracle_time/ml_time))
print('BB time: {}, ML time: {} '.format(oracle_time, ml_time))
